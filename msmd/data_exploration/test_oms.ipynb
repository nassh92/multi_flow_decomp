# %%
import os
os.chdir('C:\\Users\\HADDAM\\Documents\\Python Scripts\\multi_flow_decomp\\')
import pickle
import osmnx as ox
import sys
from pre_process_data_osm.pre_process_osm import get_osm_map


# Versailles gran parc agglomeration
AGGLOMERATION_AREA_NAMES = ["Bailly, Yvelines, France", 
                            "Bièvres, Yvelines, France", 
                            "Bois d'Arcy, Yvelines, France", 
                            "Bougival, Yvelines, France", 
                            "Buc, Yvelines, France", 
                            "Châteaufort, Yvelines, France", 
                            "Fontenay-Le-Fleury, Yvelines, France", 
                            "Jouy-En-Josas, Yvelines, France", 
                            "La Celle Saint-Cloud, Yvelines, France", 
                            "Le Chesnay-Rocquencourt, Yvelines, France", 
                            "Les Loges-En-Josas, Yvelines, France", 
                            "Noisy-Le-Roi, Yvelines, France", 
                            "Rennemoulin, Yvelines, France", 
                            "Saint-Cyr-l'École, Yvelines, France", 
                            "Toussus-Le-Noble, Yvelines, France", 
                            "Vélizy-Villacoublay, Yvelines, France", 
                            "Versailles, Yvelines, France", 
                            "Viroflay, Yvelines, France"]

# The testnames
test_names = {"get_osm_versailles_grand_parc",
              "get_osm_versailles",
              "get_osm_lieusaint", 
              "read_osm"}

# The selected test name
test_name = "get_osm_versailles_grand_parc"


if test_name == "get_osm_versailles_grand_parc":
    path_file = "data/original_graphs/versailles_grand_parc.gpickle"
    g = get_osm_map(AGGLOMERATION_AREA_NAMES,
                    path_file = path_file)
    
elif test_name == "get_osm_versailles":
    path_file = "data/original_graphs/versailles.gpickle"
    g = get_osm_map(["Versailles, Yvelines, France",
                     "Le Chesnay-Rocquencourt, Yvelines, France"],
                    path_file = path_file)

elif test_name == "get_osm_lieusaint":
    path_file = "data/original_graphs/lieusaint.gpickle"
    g = get_osm_map("Lieusaint, Seine-et-Marne, France",
                    path_file = path_file)

elif test_name == "read_osm":
    path_file = "data/original_graphs/versailles_grand_parc.gpickle"
    with open(path_file, 'rb') as f:
        g = pickle.load(f)

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]
plt.plot(x, y)
